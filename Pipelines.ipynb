# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("housing.csv")

# %%
# creating a new df for out model training (we need an income for ranking)

df["income_cat"] = pd.cut(df["median_income"], bins = [0, 1.5, 3.0, 4.5, 6.0, np.inf], labels = [1,2, 3, 4,5])

# %%
from sklearn.model_selection import StratifiedShuffleSplit
split = StratifiedShuffleSplit(n_splits= 1, random_state=42, test_size=0.2)

for train_index, test_index in split.split(df, df["income_cat"]):
    strat_train_set = df.loc[train_index]
    strat_test_set = df.loc[test_index]

# %%
#lets remove the income _ cat column
for sett in (strat_train_set, strat_test_set):
    sett.drop("income_cat", axis=1, inplace =True)

# %%
# Lets save the copy for strata train test as we are going to do so many things with this set (we save it inside df)
df = strat_train_set.copy()

# %%
df = strat_train_set.drop("median_house_value", axis =1)
housing_labels = strat_train_set["median_house_value"].copy

# %%
df = df.drop("ocean_proximity", axis = 1)
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12655    -121.46     38.52                29.0       3873.0           797.0
# 15502    -117.23     33.09                 7.0       5320.0           855.0
# 2908     -119.04     35.37                44.0       1618.0           310.0
# 14053    -117.13     32.75                24.0       1877.0           519.0
# 20496    -118.70     34.28                27.0       3536.0           646.0
# ...          ...       ...                 ...          ...             ...
# 15174    -117.07     33.03                14.0       6665.0          1231.0
# 12661    -121.42     38.51                15.0       7901.0          1422.0
# 19263    -122.72     38.44                48.0        707.0           166.0
# 19140    -122.70     38.31                14.0       3155.0           580.0
# 19773    -122.14     39.97                27.0       1079.0           222.0
#
#        population  households  median_income
# ...

# %% [markdown]
# ## Constructing Pipelines

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

# %%
my_pipeline = Pipeline([("impute", SimpleImputer(strategy="mean")),("standard", StandardScaler()), ])

# %%
my_pipeline.fit_transform(df)
# Out:
# array([[-0.94135046,  1.34743822,  0.02756357, ...,  0.73260236,
#          0.55628602, -0.8936472 ],
#        [ 1.17178212, -1.19243966, -1.72201763, ...,  0.53361152,
#          0.72131799,  1.292168  ],
#        [ 0.26758118, -0.1259716 ,  1.22045984, ..., -0.67467519,
#         -0.52440722, -0.52543365],
#        ...,
#        [-1.5707942 ,  1.31001828,  1.53856552, ..., -0.86201341,
#         -0.86511838, -0.36547546],
#        [-1.56080303,  1.2492109 , -1.1653327 , ..., -0.18974707,
#          0.01061579,  0.16826095],
#        [-1.28105026,  2.02567448, -0.13148926, ..., -0.71232211,
#         -0.79857323, -0.390569  ]])

# %% [markdown]
# ## Model Training
# ### Final Pipeline
